# %% [markdown]
# # Explore real AirPassengers data
#
# This notebook uses the bundled real monthly passenger dataset, not synthetic generated data.

# %%
from timesfm_practice.data import load_air_passengers, train_test_split_time

df = load_air_passengers('../data/raw/air_passengers.csv')
df.head()

# %%
ax = df.plot(x='timestamp', y='value', title='AirPassengers monthly totals')
ax.set_xlabel('Month')
ax.set_ylabel('Passengers, thousands')

# %%
train, test = train_test_split_time(df, horizon=12)
len(train), len(test), train.tail(2), test.head(2)
